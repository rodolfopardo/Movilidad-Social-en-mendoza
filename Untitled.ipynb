# %%
#Se importan librerias necesarias 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
sns.set(rc={'figure.figsize':(11.7,8.27)})
import plotly.express as px
import matplotlib.dates as mdates
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
gglobal = pd.read_csv('/Users/rodolfopardo/Downloads/Global_Mobility_Report (6).csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning:
#
# Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
gglobal.shape
# Out:
# (2551112, 14)

# %%
#Filtramos Argentina

argentina = gglobal[gglobal['country_region']== "Argentina"]

# %%
argentina['sub_region_1'].value_counts(normalize = True)
# Out:
# Buenos Aires Province           0.301099
# Cordoba                         0.055337
# Santa Fe Province               0.048511
# Mendoza Province                0.044971
# Chaco Province                  0.043328
# Tucumán                         0.041949
# Corrientes                      0.041872
# Entre Rios                      0.040306
# Buenos Aires                    0.038817
# Misiones Province               0.038112
# Salta Province                  0.033568
# La Pampa                        0.032454
# San Juan Province               0.028848
# Santiago del Estero Province    0.028716
# Neuquen                         0.025397
# Jujuy                           0.023908
# Río Negro                       0.023335
# Catamarca Province              0.021195
# Chubut Province                 0.019078
# San Luis Province               0.018019
# Santa Cruz Province             0.016486
# La Rioja Province               0.014325
# Formosa Province                0.013090
# ...

# %%
mendoza = argentina[argentina['sub_region_1'] == "Mendoza Province"]

# %%
mendoza['date'] = pd.to_datetime(mendoza['date'])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mendoza = mendoza[['sub_region_2', 'date', 'retail_and_recreation_percent_change_from_baseline',
                   'grocery_and_pharmacy_percent_change_from_baseline',
                   'parks_percent_change_from_baseline', 
                   'transit_stations_percent_change_from_baseline', 
                   'workplaces_percent_change_from_baseline', 
                   'residential_percent_change_from_baseline']]

# %%
columnas = ['departamento', 'fecha', 'ocio_y_recreacion', 'supermercados_y_farmcias', 'parques', 'transporte',
           'lugares_de_trabajo', 'zonas_residenciales']
mendoza.columns = columnas

# %%
#Tiempo y Ocio

sns.lineplot(x = "fecha", y = "ocio_y_recreacion", data = mendoza, estimator = "mean")
plt.title('Ocio y recreación en Mendoza', fontsize = 20)
plt.ylabel('Porcentaje de variación')
plt.xlabel('Fecha')
plt.show()

# %%
gran_mendoza = mendoza[(mendoza.departamento == "Maipú Department") | 
        (mendoza.departamento == 'Guaymallén Department') |
        (mendoza.departamento == "Capital Department") | 
        (mendoza.departamento == "Las Heras Department") | 
        (mendoza.departamento == "Luján de Cuyo Department") | 
        (mendoza.departamento == "Godoy Cruz Department")
       ]

valle_de_uco = mendoza[(mendoza.departamento == "Tupungato Department") | 
                       (mendoza.departamento == "Tunuyán Department") |
                       (mendoza.departamento == "San Carlos Department")]

# %%
#Grafica Departamentos

sns.lineplot(x = "fecha", y = "ocio_y_recreacion", data = gran_mendoza, hue = "departamento")
plt.title('Ocio y recreación por departamento', fontsize = 20)
plt.ylabel('Porcentaje de variación')
plt.xlabel('Fecha')
plt.show()

# %%
gran_mendoza.tail()
# Out:
#            departamento      fecha  ocio_y_recreacion  \
# 65096  Maipú Department 2020-09-17                NaN
# 65097  Maipú Department 2020-09-18                NaN
# 65098  Maipú Department 2020-09-19                NaN
# 65099  Maipú Department 2020-09-20                NaN
# 65100  Maipú Department 2020-09-21                NaN
#
#        supermercados_y_farmcias  parques  transporte  lugares_de_trabajo  \
# 65096                       NaN      NaN         NaN               -20.0
# 65097                       NaN      NaN         NaN               -18.0
# 65098                       NaN      NaN         NaN               -11.0
# 65099                       NaN      NaN         NaN               -24.0
# 65100                       NaN      NaN         NaN               -55.0
#
#        zonas_residenciales
# 65096                 16.0
# 65097                 17.0
# 65098                 17.0
# 65099                 24.0
# 65100                 27.0
