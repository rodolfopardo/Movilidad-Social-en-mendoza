# %%
#Se importan librerias necesarias 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
sns.set(rc={'figure.figsize':(11.7,8.27)})
import plotly.express as px
import matplotlib.dates as mdates
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Se extrae la data

gglobal = pd.read_csv('/Users/rodolfopardo/Downloads/Global_Mobility_Report(2).csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning:
#
# Columns (3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
#Dimensiones de la base 

gglobal.shape
# Out:
# (5561418, 15)

# %%
#Columnas 

gglobal.columns
# Out:
# Index(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
#        'metro_area', 'iso_3166_2_code', 'census_fips_code', 'place_id', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %%
gglobal.head()
# Out:
#   country_region_code        country_region sub_region_1 sub_region_2  \
# 0                  AE  United Arab Emirates          NaN          NaN
# 1                  AE  United Arab Emirates          NaN          NaN
# 2                  AE  United Arab Emirates          NaN          NaN
# 3                  AE  United Arab Emirates          NaN          NaN
# 4                  AE  United Arab Emirates          NaN          NaN
#
#   metro_area iso_3166_2_code  census_fips_code                     place_id  \
# 0        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 1        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 2        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 3        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 4        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
#
#          date  retail_and_recreation_percent_change_from_baseline  \
# ...

# %%
gglobal.tail()
# Out:
#         country_region_code country_region       sub_region_1 sub_region_2  \
# 5561413                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 5561414                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 5561415                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 5561416                  ZW       Zimbabwe  Midlands Province       Kwekwe
# 5561417                  ZW       Zimbabwe  Midlands Province       Kwekwe
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 5561413        NaN             NaN               NaN
# 5561414        NaN             NaN               NaN
# 5561415        NaN             NaN               NaN
# 5561416        NaN             NaN               NaN
# 5561417        NaN             NaN               NaN
#
#                             place_id        date  \
# 5561413  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-05-24
# 5561414  ChIJRcIZ3-FJNBkRRsj55IcLpfU  2021-05-25
# ...

# %%
gglobal.dtypes
# Out:
# country_region_code                                    object
# country_region                                         object
# sub_region_1                                           object
# sub_region_2                                           object
# metro_area                                             object
# iso_3166_2_code                                        object
# census_fips_code                                      float64
# place_id                                               object
# date                                                   object
# retail_and_recreation_percent_change_from_baseline    float64
# grocery_and_pharmacy_percent_change_from_baseline     float64
# parks_percent_change_from_baseline                    float64
# transit_stations_percent_change_from_baseline         float64
# workplaces_percent_change_from_baseline               float64
# residential_percent_change_from_baseline              float64
# dtype: object

# %%
gglobal.isnull().sum()
# Out:
# country_region_code                                      3544
# country_region                                              0
# sub_region_1                                            93443
# sub_region_2                                           916795
# metro_area                                            5531068
# iso_3166_2_code                                       4575765
# census_fips_code                                      4387283
# place_id                                                10068
# date                                                        0
# retail_and_recreation_percent_change_from_baseline    2091375
# grocery_and_pharmacy_percent_change_from_baseline     2225445
# parks_percent_change_from_baseline                    2893556
# transit_stations_percent_change_from_baseline         2766994
# workplaces_percent_change_from_baseline                229614
# residential_percent_change_from_baseline              2271302
# dtype: int64

# %%
#Filtramos Argentina

argentina = gglobal[gglobal['country_region']== "Argentina"]

# %%
argentina.shape
# Out:
# (195097, 15)

# %%
argentina['sub_region_1'].value_counts(normalize = True).to_frame()
# Out:
#                               sub_region_1
# Buenos Aires Province             0.298467
# Cordoba                           0.054756
# Santa Fe Province                 0.047732
# Chaco Province                    0.045456
# Mendoza Province                  0.044223
# Corrientes                        0.043252
# Tucumán                           0.041685
# Entre Rios                        0.039927
# Buenos Aires                      0.038556
# Misiones Province                 0.037980
# La Pampa                          0.034913
# Salta Province                    0.032827
# San Juan Province                 0.028983
# Santiago del Estero Province      0.028773
# Neuquen                           0.024894
# Río Negro                         0.023974
# Jujuy                             0.023291
# Catamarca Province                0.021574
# Chubut Province                   0.018774
# San Luis Province                 0.018117
# Santa Cruz Province               0.016221
# ...

# %%
#Filtramos Mendoza

mendoza = argentina[argentina['sub_region_1'] == "Mendoza Province"]

# %%
mendoza.shape
# Out:
# (8607, 15)

# %%
#Pasamos los valores de fechas a su correspondiente tipo de dato

mendoza['date'] = pd.to_datetime(mendoza['date'])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mendoza.columns
# Out:
# Index(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
#        'metro_area', 'iso_3166_2_code', 'census_fips_code', 'place_id', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %%
#Filtrado de informacion 

mendoza = mendoza[['sub_region_2', 'date', 'retail_and_recreation_percent_change_from_baseline',
                   'grocery_and_pharmacy_percent_change_from_baseline',
                   'parks_percent_change_from_baseline', 
                   'transit_stations_percent_change_from_baseline', 
                   'workplaces_percent_change_from_baseline', 
                   'residential_percent_change_from_baseline']]

# %%
#DataFrame general de trabajo

mendoza.head()
# Out:
#        sub_region_2       date  \
# 135289          NaN 2020-02-15
# 135290          NaN 2020-02-16
# 135291          NaN 2020-02-17
# 135292          NaN 2020-02-18
# 135293          NaN 2020-02-19
#
#         retail_and_recreation_percent_change_from_baseline  \
# 135289                                                8.0
# 135290                                                3.0
# 135291                                                6.0
# 135292                                                5.0
# 135293                                                6.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 135289                                               -1.0
# 135290                                               -3.0
# 135291                                                3.0
# 135292                                               -1.0
# 135293                                                0.0
#
#         parks_percent_change_from_baseline  \
# ...

# %%
#Cambiamos columnas de nombres

mendoza.columns
# Out:
# Index(['sub_region_2', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %%
columnas = ['departamento', 'fecha', 'ocio_y_recreacion', 'supermercados_y_farmcias', 'parques', 'transporte',
           'lugares_de_trabajo', 'zonas_residenciales']
mendoza.columns = columnas

# %%
mendoza.head()
# Out:
#        departamento      fecha  ocio_y_recreacion  supermercados_y_farmcias  \
# 135289          NaN 2020-02-15                8.0                      -1.0
# 135290          NaN 2020-02-16                3.0                      -3.0
# 135291          NaN 2020-02-17                6.0                       3.0
# 135292          NaN 2020-02-18                5.0                      -1.0
# 135293          NaN 2020-02-19                6.0                       0.0
#
#         parques  transporte  lugares_de_trabajo  zonas_residenciales
# 135289      0.0         2.0                 2.0                  0.0
# 135290     -2.0         0.0                -2.0                  1.0
# 135291     -1.0        10.0                17.0                 -1.0
# 135292     -1.0         7.0                19.0                 -1.0
# 135293     -1.0         5.0                19.0                 -1.0

# %%
mayo = mendoza[mendoza['fecha'] >= '2021-05-20']

# %%
mayo.shape
# Out:
# (170, 8)

# %%
mayo.head(10)
# Out:
#               departamento      fecha  ocio_y_recreacion  \
# 135749                 NaN 2021-05-20              -23.0
# 135750                 NaN 2021-05-21              -13.0
# 135751                 NaN 2021-05-22              -57.0
# 135752                 NaN 2021-05-23              -64.0
# 135753                 NaN 2021-05-24              -64.0
# 135754                 NaN 2021-05-25              -71.0
# 135755                 NaN 2021-05-26              -49.0
# 135756                 NaN 2021-05-27              -47.0
# 135757                 NaN 2021-05-28              -46.0
# 136218  Capital Department 2021-05-20              -35.0
#
#         supermercados_y_farmcias  parques  transporte  lugares_de_trabajo  \
# 135749                       7.0    -50.0       -22.0                15.0
# 135750                      29.0    -46.0       -18.0                16.0
# 135751                      -6.0    -73.0       -47.0               -19.0
# ...

# %%
mayo.columns
# Out:
# Index(['departamento', 'fecha', 'ocio_y_recreacion',
#        'supermercados_y_farmcias', 'parques', 'transporte',
#        'lugares_de_trabajo', 'zonas_residenciales'],
#       dtype='object')

# %%
sns.boxplot(mayo['ocio_y_recreacion'], color = "green")
plt.title("Distribución de variable ocio y recreación", fontsize = 20)
plt.xlabel('Porcentaje de variación')
plt.show()

# %%
mendoza.ocio_y_recreacion.describe()
# Out:
# count    6953.000000
# mean      -32.519344
# std        26.015148
# min       -96.000000
# 25%       -52.000000
# 50%       -32.000000
# 75%       -12.000000
# max        44.000000
# Name: ocio_y_recreacion, dtype: float64

# %%
mendoza.departamento.value_counts()
# Out:
# Rivadavia Department         469
# Maipú Department             469
# Godoy Cruz Department        469
# Capital Department           469
# Luján de Cuyo Department     469
# Las Heras Department         469
# San Rafael Department        469
# Guaymallén Department        469
# Tunuyán Department           468
# San Martín Department        467
# Junín Department             466
# General Alvear Department    462
# Santa Rosa Department        444
# San Carlos Department        444
# Tupungato Department         444
# Malargüe Department          444
# Lavalle Department           438
# La Paz Department            309
# Name: departamento, dtype: int64

# %%
#Filtro Gran Mendoza

gran_mendoza = mayo[(mayo.departamento == "Maipú Department") | 
        (mayo.departamento == 'Guaymallén Department') |
        (mayo.departamento == "Capital Department") | 
        (mayo.departamento == "Las Heras Department") | 
        (mayo.departamento == "Luján de Cuyo Department") | 
        (mayo.departamento == "Godoy Cruz Department")
       ]

valle_de_uco = mayo[(mayo.departamento == "Tupungato Department") | 
                       (mayo.departamento == "Tunuyán Department") |
                       (mayo.departamento == "San Carlos Department")]

# %%
#Conociendo variables Gran Mendoza

gran_mendoza.tail()
# Out:
#             departamento      fecha  ocio_y_recreacion  \
# 140242  Maipú Department 2021-05-24              -56.0
# 140243  Maipú Department 2021-05-25              -65.0
# 140244  Maipú Department 2021-05-26              -39.0
# 140245  Maipú Department 2021-05-27              -37.0
# 140246  Maipú Department 2021-05-28              -37.0
#
#         supermercados_y_farmcias  parques  transporte  lugares_de_trabajo  \
# 140242                      -8.0    -69.0       -41.0               -53.0
# 140243                     -28.0    -74.0       -44.0               -64.0
# 140244                       1.0    -67.0       -24.0               -11.0
# 140245                      14.0    -66.0       -21.0               -12.0
# 140246                      12.0    -66.0       -22.0                -6.0
#
#         zonas_residenciales
# 140242                 24.0
# 140243                 26.0
# 140244                 18.0
# 140245                 18.0
# 140246                 19.0

# %%
#Grafica Departamentos

sns.lineplot(x = "fecha", y = "ocio_y_recreacion", data = gran_mendoza, hue = "departamento")
plt.title('Ocio y recreación por departamento', fontsize = 20)
plt.ylabel('Porcentaje de variación')
plt.xlabel('Fecha')
plt.show()

# %%
#Grafica Departamentos

sns.lineplot(x = "fecha", y = "lugares_de_trabajo", data = gran_mendoza, hue = "departamento")
plt.title('Lugares de trabajo', fontsize = 20)
plt.ylabel('Porcentaje de variación')
plt.xlabel('Fecha')
plt.show()

# %%
sns.lineplot(x = "fecha", y = "ocio_y_recreacion", data = valle_de_uco, hue = "departamento")
plt.title('Ocio y recreación por departamento', fontsize = 20)
plt.ylabel('Porcentaje de variación')
plt.xlabel('Fecha')
plt.show()

# %%
#Grafica Supermercados

sns.lineplot(x = "fecha", y = "supermercados_y_farmcias", data = gran_mendoza, hue = "departamento")
plt.title('Supermercados y Farmacias', fontsize = 20)
plt.ylabel('Porcentaje de variación')
plt.xlabel('Fecha')
plt.show()

# %%
sns.distplot(gran_mendoza['supermercados_y_farmcias'], color = "blue")
plt.title('Oscilación de variables en Supermercados y Farmacias', fontsize = 20)
plt.ylabel('Porcentaje de variación')
plt.xlabel('Fecha')
plt.show()

# %%
#Grafica Parques

sns.lineplot(x = "fecha", y = "parques", data = gran_mendoza, hue = "departamento")
plt.title('Parques', fontsize = 20)
plt.ylabel('Porcentaje de variación')
plt.xlabel('Fecha')
plt.show()

# %%
#Grafica Transporte

sns.lineplot(x = "fecha", y = "transporte", data = gran_mendoza, hue = "departamento")
plt.title('Actividad en transporte', fontsize = 20)
plt.ylabel('Porcentaje de variación')
plt.xlabel('Fecha')
plt.show()

# %%
sns.distplot(gran_mendoza['transporte'], color = "red")
plt.title('Oscilación de variables en Supermercados y Farmacias', fontsize = 20)
plt.ylabel('Porcentaje de variación')
plt.xlabel('Fecha')
plt.show()

# %%
#Grafica Trabajo

sns.lineplot(x = "fecha", y = "lugares_de_trabajo", data = gran_mendoza, hue = "departamento")
plt.title('Lugares de trabajo', fontsize = 20)
plt.ylabel('Porcentaje de variación')
plt.xlabel('Fecha')
plt.show()

# %%
#Grafica Residencias

sns.lineplot(x = "fecha", y = "zonas_residenciales", data = gran_mendoza, hue = "departamento")
plt.title('Zonas residenciales', fontsize = 20)
plt.ylabel('Porcentaje de variación')
plt.xlabel('Fecha')
plt.show()
