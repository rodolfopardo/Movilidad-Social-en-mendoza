# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/rodolfopardo/Downloads/Global_Mobility_Report(1).csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   country_region_code        country_region sub_region_1 sub_region_2  \
# 0                  AE  United Arab Emirates          NaN          NaN
# 1                  AE  United Arab Emirates          NaN          NaN
# 2                  AE  United Arab Emirates          NaN          NaN
# 3                  AE  United Arab Emirates          NaN          NaN
# 4                  AE  United Arab Emirates          NaN          NaN
#
#   metro_area iso_3166_2_code  census_fips_code                     place_id  \
# 0        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 1        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 2        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 3        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 4        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
#
#          date  retail_and_recreation_percent_change_from_baseline  \
# ...

# %%
argentina = data[data['country_region'] == "Argentina"]

# %%
argentina.shape
# Out:
# (193337, 15)

# %%
argentina.tail()
# Out:
#        country_region_code country_region sub_region_1  \
# 202076                  AR      Argentina      Tucumán
# 202077                  AR      Argentina      Tucumán
# 202078                  AR      Argentina      Tucumán
# 202079                  AR      Argentina      Tucumán
# 202080                  AR      Argentina      Tucumán
#
#                   sub_region_2 metro_area iso_3166_2_code  census_fips_code  \
# 202076  Yerba Buena Department        NaN             NaN               NaN
# 202077  Yerba Buena Department        NaN             NaN               NaN
# 202078  Yerba Buena Department        NaN             NaN               NaN
# 202079  Yerba Buena Department        NaN             NaN               NaN
# 202080  Yerba Buena Department        NaN             NaN               NaN
#
#                            place_id        date  \
# 202076  ChIJV8nJu3BCIpQRv6clokbuEko  2021-05-20
# 202077  ChIJV8nJu3BCIpQRv6clokbuEko  2021-05-21
# ...
